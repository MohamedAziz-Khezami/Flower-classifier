# %% [markdown]
# ## **IRIS Flowers classifier**
#
# - This model aims to classify the a dataset of iris flowers based on some folwer characteristics: SepalLengthCm	SepalWidthCm	PetalLengthCm	PetalWidthCm
# - The target is: 'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC  # Support Vector Classifier
from fasteda import fast_eda
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\nki\Desktop\flower\Iris.csv')

# %%
df_test = df.loc[0:5]

# %%
df['Species'] = df['Species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
fast_eda(df)
# Out:
# DataFrame Head:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# DataFrame Tail:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# </style>
# <table id="T_cc470">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc470_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (150, 6)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# Name: count, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id                75.5
# SepalLengthCm    5.843
# SepalWidthCm     3.054
# PetalLengthCm    3.759
# PetalWidthCm     1.199
# Species              1
# Name: mean, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               75.5
# SepalLengthCm     5.8
# SepalWidthCm        3
# PetalLengthCm    4.35
# PetalWidthCm      1.3
# Species             1
# Name: median, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               43.445
# SepalLengthCm     0.828
# SepalWidthCm      0.434
# PetalLengthCm     1.764
# PetalWidthCm      0.763
# Species           0.819
# Name: std, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id                 1
# SepalLengthCm    4.3
# SepalWidthCm       2
# PetalLengthCm      1
# PetalWidthCm     0.1
# Species            0
# Name: min, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               38.25
# SepalLengthCm      5.1
# SepalWidthCm       2.8
# PetalLengthCm      1.6
# PetalWidthCm       0.3
# Species              0
# Name: 25%, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               75.5
# SepalLengthCm     5.8
# SepalWidthCm        3
# PetalLengthCm    4.35
# PetalWidthCm      1.3
# Species             1
# Name: 50%, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               112.75
# SepalLengthCm       6.4
# SepalWidthCm        3.3
# PetalLengthCm       5.1
# PetalWidthCm        1.8
# Species               2
# Name: 75%, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:86: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Id               150
# SepalLengthCm    7.9
# SepalWidthCm     4.4
# PetalLengthCm    6.9
# PetalWidthCm     2.5
# Species            2
# Name: max, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# C:\Users\nki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\fasteda\__init__.py:92: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_negative_red, subset = info_cols)
# <style type="text/css">
# #T_ea3f5_row0_col0, #T_ea3f5_row1_col0, #T_ea3f5_row2_col0, #T_ea3f5_row2_col3, #T_ea3f5_row3_col0, #T_ea3f5_row4_col0, #T_ea3f5_row4_col1, #T_ea3f5_row4_col7, #T_ea3f5_row4_col8, #T_ea3f5_row5_col0, #T_ea3f5_row5_col1, #T_ea3f5_row5_col2, #T_ea3f5_row5_col4, #T_ea3f5_row5_col5, #T_ea3f5_row5_col6, #T_ea3f5_row5_col7, #T_ea3f5_row5_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row0_col1, #T_ea3f5_row0_col2, #T_ea3f5_row0_col3, #T_ea3f5_row0_col5, #T_ea3f5_row0_col6, #T_ea3f5_row0_col7, #T_ea3f5_row0_col8, #T_ea3f5_row1_col4 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row0_col4, #T_ea3f5_row3_col4 {
#   background-color: #f7814c;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row0_col9, #T_ea3f5_row5_col9 {
#   color: #FFFFFF;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_ea3f5_row0_col10, #T_ea3f5_row1_col10, #T_ea3f5_row3_col9, #T_ea3f5_row3_col10, #T_ea3f5_row4_col9, #T_ea3f5_row4_col10, #T_ea3f5_row5_col10 {
#   color: #ff0000;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_ea3f5_row1_col1, #T_ea3f5_row1_col2, #T_ea3f5_row1_col6 {
#   background-color: #c1274a;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row1_col3, #T_ea3f5_row4_col5, #T_ea3f5_row5_col3 {
#   background-color: #a20643;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row1_col5 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row1_col7, #T_ea3f5_row1_col8, #T_ea3f5_row3_col5 {
#   background-color: #b41947;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row1_col9, #T_ea3f5_row2_col9, #T_ea3f5_row2_col10 {
#   color: #00ff00;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_ea3f5_row2_col1, #T_ea3f5_row3_col3, #T_ea3f5_row3_col7 {
#   background-color: #ad1246;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row2_col2, #T_ea3f5_row2_col6 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row2_col4 {
#   background-color: #fff5ae;
#   color: #000000;
#   font-weight: bold;
# }
# #T_ea3f5_row2_col5 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row2_col7 {
#   background-color: #a40844;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row2_col8 {
#   background-color: #a70b44;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row3_col1 {
#   background-color: #b11747;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row3_col2, #T_ea3f5_row3_col6 {
#   background-color: #b61b48;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row3_col8 {
#   background-color: #af1446;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row4_col2, #T_ea3f5_row4_col3, #T_ea3f5_row4_col6 {
#   background-color: #a00343;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_ea3f5_row4_col4 {
#   background-color: #a90d45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_ea3f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea3f5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ea3f5_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ea3f5_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_ea3f5_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_ea3f5_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_ea3f5_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_ea3f5_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_ea3f5_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_ea3f5_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_ea3f5_level0_col9" class="col_heading level0 col9" >skewness</th>
#       <th id="T_ea3f5_level0_col10" class="col_heading level0 col10" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea3f5_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_ea3f5_row0_col0" class="data row0 col0" >150</td>
#       <td id="T_ea3f5_row0_col1" class="data row0 col1" >75.5</td>
#       <td id="T_ea3f5_row0_col2" class="data row0 col2" >75.5</td>
#       <td id="T_ea3f5_row0_col3" class="data row0 col3" >43.445</td>
#       <td id="T_ea3f5_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_ea3f5_row0_col5" class="data row0 col5" >38.25</td>
#       <td id="T_ea3f5_row0_col6" class="data row0 col6" >75.5</td>
#       <td id="T_ea3f5_row0_col7" class="data row0 col7" >112.75</td>
#       <td id="T_ea3f5_row0_col8" class="data row0 col8" >150</td>
#       <td id="T_ea3f5_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_ea3f5_row0_col10" class="data row0 col10" >-1.200107</td>
#     </tr>
#     <tr>
#       <th id="T_ea3f5_level0_row1" class="row_heading level0 row1" >SepalLengthCm</th>
#       <td id="T_ea3f5_row1_col0" class="data row1 col0" >150</td>
#       <td id="T_ea3f5_row1_col1" class="data row1 col1" >5.843</td>
#       <td id="T_ea3f5_row1_col2" class="data row1 col2" >5.8</td>
#       <td id="T_ea3f5_row1_col3" class="data row1 col3" >0.828</td>
#       <td id="T_ea3f5_row1_col4" class="data row1 col4" >4.3</td>
#       <td id="T_ea3f5_row1_col5" class="data row1 col5" >5.1</td>
#       <td id="T_ea3f5_row1_col6" class="data row1 col6" >5.8</td>
#       <td id="T_ea3f5_row1_col7" class="data row1 col7" >6.4</td>
#       <td id="T_ea3f5_row1_col8" class="data row1 col8" >7.9</td>
#       <td id="T_ea3f5_row1_col9" class="data row1 col9" >0.311753</td>
#       <td id="T_ea3f5_row1_col10" class="data row1 col10" >-0.573568</td>
#     </tr>
#     <tr>
#       <th id="T_ea3f5_level0_row2" class="row_heading level0 row2" >SepalWidthCm</th>
#       <td id="T_ea3f5_row2_col0" class="data row2 col0" >150</td>
#       <td id="T_ea3f5_row2_col1" class="data row2 col1" >3.054</td>
#       <td id="T_ea3f5_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_ea3f5_row2_col3" class="data row2 col3" >0.434</td>
#       <td id="T_ea3f5_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_ea3f5_row2_col5" class="data row2 col5" >2.8</td>
#       <td id="T_ea3f5_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_ea3f5_row2_col7" class="data row2 col7" >3.3</td>
#       <td id="T_ea3f5_row2_col8" class="data row2 col8" >4.4</td>
#       <td id="T_ea3f5_row2_col9" class="data row2 col9" >0.330703</td>
#       <td id="T_ea3f5_row2_col10" class="data row2 col10" >0.241443</td>
#     </tr>
#     <tr>
#       <th id="T_ea3f5_level0_row3" class="row_heading level0 row3" >PetalLengthCm</th>
#       <td id="T_ea3f5_row3_col0" class="data row3 col0" >150</td>
#       <td id="T_ea3f5_row3_col1" class="data row3 col1" >3.759</td>
#       <td id="T_ea3f5_row3_col2" class="data row3 col2" >4.35</td>
#       <td id="T_ea3f5_row3_col3" class="data row3 col3" >1.764</td>
#       <td id="T_ea3f5_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_ea3f5_row3_col5" class="data row3 col5" >1.6</td>
#       <td id="T_ea3f5_row3_col6" class="data row3 col6" >4.35</td>
#       <td id="T_ea3f5_row3_col7" class="data row3 col7" >5.1</td>
#       <td id="T_ea3f5_row3_col8" class="data row3 col8" >6.9</td>
#       <td id="T_ea3f5_row3_col9" class="data row3 col9" >-0.271712</td>
#       <td id="T_ea3f5_row3_col10" class="data row3 col10" >-1.395359</td>
#     </tr>
#     <tr>
#       <th id="T_ea3f5_level0_row4" class="row_heading level0 row4" >PetalWidthCm</th>
#       <td id="T_ea3f5_row4_col0" class="data row4 col0" >150</td>
#       <td id="T_ea3f5_row4_col1" class="data row4 col1" >1.199</td>
#       <td id="T_ea3f5_row4_col2" class="data row4 col2" >1.3</td>
#       <td id="T_ea3f5_row4_col3" class="data row4 col3" >0.763</td>
#       <td id="T_ea3f5_row4_col4" class="data row4 col4" >0.1</td>
#       <td id="T_ea3f5_row4_col5" class="data row4 col5" >0.3</td>
#       <td id="T_ea3f5_row4_col6" class="data row4 col6" >1.3</td>
#       <td id="T_ea3f5_row4_col7" class="data row4 col7" >1.8</td>
#       <td id="T_ea3f5_row4_col8" class="data row4 col8" >2.5</td>
#       <td id="T_ea3f5_row4_col9" class="data row4 col9" >-0.103944</td>
#       <td id="T_ea3f5_
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# ----------------------------------------------------------------------------------------------------
# DataFrame Pairplot:
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):
# ----------------------------------------------------------------------------------------------------
# Countplot(s):

# %%
df = df.loc[1:140, :]

# %%
x = df.drop(['Id', 'Species'], axis=1)
y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
clf = SVC()
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
prediction = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction)
# Out:
# 0.9285714285714286

# %%
prediction
# Out:
# array([2, 1, 0, 2, 0, 0, 1, 1, 2, 2, 2, 1, 1, 0, 1, 1, 0, 0, 2, 2, 0, 1,
#        1, 0, 2, 0, 2, 1], dtype=int64)

# %%
df_test = df_test.drop(['Id', 'Species'], axis=1)
clf.predict(df_test)
# Out:
# array([0, 0, 0, 0, 0, 0], dtype=int64)
